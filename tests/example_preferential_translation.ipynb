# %%
import pandas as pd

# %%
filename = "../../Data/pipeline_training_data.jsonl"
df = pd.read_json(filename, lines=True)

# %%
df[df.source.str.contains("Pacific Ocean")].iloc[0].source

# %%
things = ['Atlantic Ocean', 'CSAS', 'espèces hôtes', 'Snow Crab']

for thing in things:
    print(thing)
    source = df[df.source.str.contains(thing)].iloc[0].source
    target = df[df.source.str.contains(thing)].iloc[0].target
    print(source)
    print(target)
    print()
